# %%
import pandas as pd

import MySQLdb

c = MySQLdb.connect('localhost', 'root', '3lihu_r007', 'rapnet_listings')

import pandas.io.sql as psql

df = psql.read_frame("""select l.LotNum, convert(l.Price, decimal) as Price, l.Shape, convert(l.Carat, decimal) as Carat, l.Color, l.Clarity, l.CutGrade, l.PctRap, l.Cert, l.Depth, l.TableWidth, l.Girdle, 
l.Culet, l.Polish, l.Sym, l.Fluor, l.Meas, l.RapnetComment, l.NumStones, l.CertNum, l.StockNum, l.Make, l.Date, l.City,
l.State, l.Country, l.Image from active_listing l where l.Cert like 'GIA' and l.Country like 'USA' 
and not l.CutGrade is null and l.CutGrade <> ''
and not l.Polish is null and l.Polish <> ''
and not l.Sym is null and l.Sym <> ''
and not l.Price is null and l.Price <> ''""", c, index_col = 'LotNum')

# %%
filtered_rows = set()
rank_dict = {'Excellent':0, 'Very Good':1, 'Good':2}

ct = 0
for idx, row in df.iterrows():
    ct += 1
    cut = rank_dict.get(row['CutGrade'], -1)
    polish = rank_dict.get(row['Polish'], -1)
    symmetry = rank_dict.get(row['Sym'], -1)
    
    if cut >= 0 and polish >= 0 and symmetry >= 0 \
    and abs(cut - polish) <= 1 and abs(polish - symmetry) <= 1 and abs(cut - symmetry) <= 1:
        filtered_rows.add(idx)
df2 = df[df.index.map(lambda x: x in filtered_rows)]

# %%
from IPython.core.display import HTML
def dump_bucket_info(minCarat, maxCarat):
    df_subset = df2[(df2.Carat >= minCarat) & (df2.Carat < maxCarat)]
    if len(df_subset) > 0:
        by_price = df_subset.sort('Price')
        firstidx = 0
        def dump_lowest_n(n):
            if len(by_price) > n and (by_price.iloc[0]['Price'] / by_price.iloc[1]['Price']) < 0.95:
                firstidx = 1 # throw out first result if more than 5% less than next one
            maxct = min(firstidx+n, len(by_price))
            display(HTML("<h4>Average of lowest {0} prices for {1} to {2} carats</h4>".format(n, minCarat, maxCarat)))
            grouped = by_price.iloc[firstidx:maxct].groupby(['CutGrade', 'Polish', 'Sym', 'Fluor']).aggregate({'Price': [np.mean, len]})
            display(HTML(grouped.to_html()))
            
        dump_lowest_n(5)
        dump_lowest_n(10)
    else:
        print 'No results'
        
dump_bucket_info(0.5, 0.7)
dump_bucket_info(0.7, 0.9)
dump_bucket_info(0.9, 1.0)
dump_bucket_info(1.0, 1.5)
dump_bucket_info(1.5, 2.0)
dump_bucket_info(2.0, 3.0)
# Out:
# No results
# No results
# No results
# <h4>Average of lowest 5 prices for 1.0 to 1.5 carats</h4>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th colspan="2" halign="left">Price</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>mean</th>
#       <th>len</th>
#     </tr>
#     <tr>
#       <th>CutGrade</th>
#       <th>Polish</th>
#       <th>Sym</th>
#       <th>Fluor</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Excellent</th>
#       <th>Very Good</th>
#       <th>Very Good</th>
#       <th>Medium </th>
#       <td> 496</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>Good</th>
#       <th>Very Good</th>
#       <th>Very Good</th>
#       <th>None </th>
#       <td> 691</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">Very Good</th>
#       <th>Excellent</th>
#       <th>Very Good</th>
#       <th>None </th>
#       <td> 568</td>
#       <td> 2</td>
#     </tr>
#     <tr>
#       <th>Very Good</th>
#       <th>Very Good</th>
#       <th>None </th>
#       <td> 684</td>
#       <td> 1</td>
#     </tr>
#   </tbody>
# </table>
# <h4>Average of lowest 10 prices for 1.0 to 1.5 carats</h4>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th colspan="2" halign="left">Price</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>mean</th>
#       <th>len</th>
#     </tr>
#     <tr>
#       <th>CutGrade</th>
#       <th>Polish</th>
#       <th>Sym</th>
#       <th>Fluor</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">Excellent</th>
#       <th>Excellent</th>
#       <th>Excellent</th>
#       <th>None </th>
#       <td> 694</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>Very Good</th>
#       <th>Very Good</th>
#       <th>Medium </th>
#       <td> 496</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">Good</th>
#       <th rowspan="2" valign="top">Very Good</th>
#       <th>Good</th>
#       <th>Medium </th>
#       <td> 700</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>Very Good</th>
#       <th>None </th>
#       <td> 691</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th rowspan="3" valign="top">Very Good</th>
#       <th rowspan="2" valign="top">Excellent</th>
#       <th>Excellent</th>
#       <th>None </th>
#       <td> 700</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>Very Good</th>
#       <th>None </th>
#       <td> 636</td>
#       <td> 4</td>
#     </tr>
#     <tr>
#       <th>Very Good</th>
#       <th>Very Good</th>
#       <th>None </th>
#       <td> 684</td>
#       <td> 1</td>
#     </tr>
#   </tbody>
# </table>
# No results
# <h4>Average of lowest 5 prices for 2.0 to 3.0 carats</h4>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th colspan="2" halign="left">Price</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>mean</th>
#       <th>len</th>
#     </tr>
#     <tr>
#       <th>CutGrade</th>
#       <th>Polish</th>
#       <th>Sym</th>
#       <th>Fluor</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="5" valign="top">Very Good</th>
#       <th>Excellent</th>
#       <th>Excellent</th>
#       <th>Medium </th>
#       <td> 1731</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">Good</th>
#       <th rowspan="2" valign="top">Good</th>
#       <th>Medium Blue</th>
#       <td> 1950</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>None </th>
#       <td>  910</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">Very Good</th>
#       <th rowspan="2" valign="top">Excellent</th>
#       <th>Medium Blue</th>
#       <td> 1840</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>None </th>
#       <td> 1820</td>
#       <td> 1</td>
#     </tr>
#   </tbody>
# </table>
# <h4>Average of lowest 10 prices for 2.0 to 3.0 carats</h4>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th colspan="2" halign="left">Price</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>mean</th>
#       <th>len</th>
#     </tr>
#     <tr>
#       <th>CutGrade</th>
#       <th>Polish</th>
#       <th>Sym</th>
#       <th>Fluor</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Good</th>
#       <th>Good</th>
#       <th>Good</th>
#       <th>Medium Blue</th>
#       <td> 1955</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th rowspan="7" valign="top">Very Good</th>
#       <th rowspan="3" valign="top">Excellent</th>
#       <th rowspan="3" valign="top">Excellent</th>
#       <th>Faint </th>
#       <td> 2142</td>
#       <td> 2</td>
#     </tr>
#     <tr>
#       <th>Medium </th>
#       <td> 1868</td>
#       <td> 2</td>
#     </tr>
#     <tr>
#       <th>Strong </th>
#       <td> 2148</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">Good</th>
#       <th rowspan="2" valign="top">Good</th>
#       <th>Medium Blue</th>
#       <td> 1950</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>None </th>
#       <td>  910</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">Very Good</th>
#       <th rowspan="2" valign="top">Excellent</th>
#       <th>Medium Blue</th>
#       <td> 1840</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>None </th>
#       <td> 1820</td>
#       <td> 1</td>
#     </tr>
#   </tbody>
# </table>
