# %%
from IPython.display import Image
i = Image(filename='/home/oliver/raspi_images/test.jpg')
i

# %%
from IPython.display import HTML
import io
import base64

video = io.open('/home/oliver/raspi_images/01-20131118124953.avi')
encoded = base64.b64encode(video)
HTML(data= '''<video alt="test" controls>
<source src="data:video/mp4;base64,{0}", type="video/mp4" />
</video>'''.format(encoded.decode('ascii')))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-35e7d8af8b8e> in <module>()
#       4
#       5 video = io.open('/home/oliver/raspi_images/01-20131118124953.avi')
# ----> 6 encoded = base64.b64encode(video)
#       7 HTML(data= '''<video alt="test" controls>
#       8 <source src="data:video/mp4;base64,{0}", type="video/mp4" />
#
# /usr/lib/python2.7/base64.pyc in b64encode(s, altchars)
#      51     """
#      52     # Strip off the trailing newline
# ---> 53     encoded = binascii.b2a_base64(s)[:-1]
#      54     if altchars is not None:
#      55         return _translate(encoded, {'+': altchars[0], '/': altchars[1]})
#
# TypeError: must be string or buffer, not _io.TextIOWrapper
